# %% [markdown]
# ### Description on the dataset
# * describe the dataset
# * give the URL of where to find the dataset and explain how to download it
# * give at least two interesting questions you have about the data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# b. load the data into a pandas dataframe

# %%
data = pd.read_csv('data/owid-covid-data.csv')
data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 184042      ZWE    Africa     Zimbabwe  2022-05-01     247911.0       36.0
# 184043      ZWE    Africa     Zimbabwe  2022-05-02     247935.0       24.0
# 184044      ZWE    Africa     Zimbabwe  2022-05-03     247990.0       55.0
# 184045      ZWE    Africa     Zimbabwe  2022-05-04     248050.0       60.0
# 184046      ZWE    Africa     Zimbabwe  2022-05-05     248050.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 184042              55.286        5469.0         0.0                0.143
# 184043              48.143        5470.0         1.0                0.286
# 184044              46.143        5470.0         0.0                0.143
# 184045              45.857        5471.0         1.0                0.286
# 184046              38.000        5471.0         0.0                0.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 184042  ...             1.6          30.7                  36.791
# 184043  ...             1.6          30.7                  36.791
# 184044  ...             1.6          30.7                  36.791
# 184045  ...             1.6          30.7                  36.791
# 184046  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 184042                         1.7            61.49                    0.571
# 184043                         1.7            61.49                    0.571
# 184044                         1.7            61.49                    0.571
# 184045                         1.7            61.49                    0.571
# 184046                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 184042                                   NaN                          NaN
# 184043                                   NaN                          NaN
# 184044                                   NaN                          NaN
# 184045                                   NaN                          NaN
# 184046                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 184042               NaN                                      NaN
# 184043               NaN                                      NaN
# 184044               NaN                                      NaN
# 184045               NaN                                      NaN
# 184046               NaN                                      NaN
#
# [184047 rows x 67 columns]

# %% [markdown]
# c. use pd.describe() to get a rough overview of the data

# %%
data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.772010e+05  1.770230e+05        1.758540e+05  1.589110e+05
# mean   3.053704e+06  1.242230e+04        1.245875e+04  6.257901e+04
# std    1.909631e+07  8.822604e+04        8.664873e+04  3.267975e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.477000e+03  0.000000e+00        6.714000e+00  9.000000e+01
# 50%    3.284000e+04  7.500000e+01        1.040000e+02  8.640000e+02
# 75%    3.557860e+05  1.056000e+03        1.161000e+03  8.159500e+03
# max    5.161695e+08  4.089131e+06        3.437057e+06  6.247502e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  158917.000000        157760.000000            176382.000000
# mean      162.953567           163.892018             37587.841979
# std       804.592952           787.692154             69722.005386
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.143000               720.774000
# 50%         1.000000             2.286000              5813.172000
# 75%        18.000000            20.143000             46883.024000
# max     18144.000000         14783.286000            706541.904000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          176204.000000                   175040.000000
# mean              182.975083                      182.999721
# std               753.898840                      575.936325
# min                 0.000000                        0.000000
# 25%                 0.002000                        1.553000
# 50%                10.826500                       19.193000
# 75%               103.104750                      127.488500
# max             51427.491000                    16052.608000
#
#        total_deaths_per_million  ...  female_smokers   male_smokers  \
# count             158105.000000  ...   115034.000000  113457.000000
# mean                 563.596770  ...       10.646529      32.788760
# std                  847.158829  ...       10.584292      13.526595
# min                    0.000000  ...        0.100000       7.700000
# 25%                   21.426000  ...        1.900000      21.600000
# 50%                  154.004000  ...        6.300000      31.400000
# 75%                  806.232000  ...       19.300000      41.300000
# max                 6382.186000  ...       44.000000      78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            74722.000000               134475.000000    172076.000000
# mean                50.947939                    3.032775        73.654343
# std                 31.861289                    2.449952         7.461146
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        69.500000
# 50%                 49.839000                    2.400000        75.050000
# 75%                 83.241000                    4.000000        79.190000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            148140.000000                          6.359000e+03
# mean                  0.725314                          3.930037e+04
# std                   0.149742                          1.099822e+05
# min                   0.394000                         -3.772610e+04
# 25%                   0.602000                         -2.325000e+01
# 50%                   0.743000                          3.760000e+03
# 75%                   0.845000                          2.636220e+04
# max                   0.957000                          1.213593e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  6359.000000       6359.000000
# mean                      9.624487         15.721005
# std                      16.028028         29.110422
# min                     -28.450000        -95.920000
# 25%                      -0.235000         -0.320000
# 50%                       6.420000          7.540000
# 75%                      14.535000         22.090000
# max                     111.010000        375.000000
#
#        excess_mortality_cumulative_per_million
# count                              6359.000000
# mean                               1075.789054
# std                                1529.209825
# min                               -1826.595723
# 25%                                  -9.703225
# 50%                                 531.704785
# 75%                                1731.057119
# max                                9713.883035
#
# [8 rows x 62 columns]

# %% [markdown]
# d. analyze your data using the following features
# - print the array of columns and the index array
# - create some simple plot of part of the data
# - create a pivot table and plot some data from that pivot table
# - use the groupby feature

# %% [markdown]
# d. (1) Analyze the data by printing the array of columns and the index array

# %%
month = [date[:7] for date in data['date']]
data['month'] = month

# %%
data['month'][:10]
# Out:
# 0    2020-02
# 1    2020-02
# 2    2020-02
# 3    2020-02
# 4    2020-02
# 5    2020-02
# 6    2020-03
# 7    2020-03
# 8    2020-03
# 9    2020-03
# Name: month, dtype: object

# %%
data_that_month = data[data['month']=='2022-01']
data_that_month
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 677         AFG      Asia  Afghanistan  2022-01-01     158107.0       23.0
# 678         AFG      Asia  Afghanistan  2022-01-02     158189.0       82.0
# 679         AFG      Asia  Afghanistan  2022-01-03     158183.0        NaN
# 680         AFG      Asia  Afghanistan  2022-01-04     158205.0       22.0
# 681         AFG      Asia  Afghanistan  2022-01-05     158245.0       40.0
# ...         ...       ...          ...         ...          ...        ...
# 183948      ZWE    Africa     Zimbabwe  2022-01-27     229096.0      153.0
# 183949      ZWE    Africa     Zimbabwe  2022-01-28     229333.0      237.0
# 183950      ZWE    Africa     Zimbabwe  2022-01-29     229415.0       82.0
# 183951      ZWE    Africa     Zimbabwe  2022-01-30     229460.0       45.0
# 183952      ZWE    Africa     Zimbabwe  2022-01-31     229666.0      206.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 677                 30.286        7356.0         0.0                1.000
# 678                 34.000        7361.0         5.0                1.000
# 679                    NaN        7364.0         3.0                1.429
# 680                 30.429        7365.0         1.0                1.429
# 681                 30.571        7367.0         2.0                1.571
# ...                    ...           ...         ...                  ...
# 183948             220.571        5324.0         3.0                6.857
# 183949             196.000        5333.0         9.0                6.429
# 183950             176.571        5333.0         0.0                5.857
# 183951             172.286        5337.0         4.0                6.143
# 183952             160.714        5338.0         1.0                4.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 677     ...           NaN                  37.746                         0.5
# 678     ...           NaN                  37.746                         0.5
# 679     ...           NaN                  37.746                         0.5
# 680     ...           NaN                  37.746                         0.5
# 681     ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 183948  ...          30.7                  36.791                         1.7
# 183949  ...          30.7                  36.791                         1.7
# 183950  ...          30.7                  36.791                         1.7
# 183951  ...          30.7                  36.791                         1.7
# 183952  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  \
# 677               64.83                    0.511
# 678               64.83                    0.511
# 679               64.83                    0.511
# 680               64.83                    0.511
# 681               64.83                    0.511
# ...                 ...                      ...
# 183948            61.49                    0.571
# 183949            61.49                    0.571
# 183950            61.49                    0.571
# 183951            61.49                    0.571
# 183952            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 677                                      NaN                          NaN
# 678                                      NaN                          NaN
# 679                                      NaN                          NaN
# 680                                      NaN                          NaN
# 681                                      NaN                          NaN
# ...                                      ...                          ...
# 183948                                   NaN                          NaN
# 183949                                   NaN                          NaN
# 183950                                   NaN                          NaN
# 183951                                   NaN                          NaN
# 183952                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million    month
# 677                  NaN                                      NaN  2022-01
# 678                  NaN                                      NaN  2022-01
# 679                  NaN                                      NaN  2022-01
# 680                  NaN                                      NaN  2022-01
# 681                  NaN                                      NaN  2022-01
# ...                  ...                                      ...      ...
# 183948               NaN                                      NaN  2022-01
# 183949               NaN                                      NaN  2022-01
# 183950               NaN                                      NaN  2022-01
# 183951               NaN                                      NaN  2022-01
# 183952               NaN                                      NaN  2022-01
#
# [7378 rows x 68 columns]

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %% [markdown]
# d. (2) Analyze the data by creating some simple plot of part of the data

# %%
data2 = data[data['iso_code']=='USA']
data2.plot(x='date', y='positive_rate')
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# d. (3) create a pivot table and plot some data from that pivot table

# %%
cleandata = []
for i in data['new_vaccinations']:
    if np.isnan(i):
        cleandata.append(0);
    else:
        cleandata.append(i);
data['new_vaccinations'] = cleandata

# %%
data3 = data.pivot_table(values='hosp_patients', index=['month'], columns=['continent'])
data3
# Out:
# continent    Africa         Asia       Europe  North America      Oceania  \
# month
# 2020-01         NaN          NaN     1.000000            NaN          NaN
# 2020-02         NaN          NaN    84.550000            NaN          NaN
# 2020-03         NaN   500.631579  1838.838407     120.478261   426.000000
# 2020-04      260.00  1031.131148  3859.447403    1963.400000   225.333333
# 2020-05      697.20   511.863636  2119.450000    2756.612903    44.838710
# 2020-06     2842.00   237.562500  1009.814077    1318.333333    17.333333
# 2020-07     6828.25   497.880597   719.966887   15824.291667   149.903226
# 2020-08     8659.80   854.606061   665.168734   19666.225806   603.838710
# 2020-09     5271.75  1054.169231   912.121019   13883.500000   163.100000
# 2020-10     5035.20  1406.242424  2389.508557   18106.790323    25.548387
# 2020-11     5102.50  1728.921875  6141.135508   36143.600000    21.500000
# 2020-12     6340.00  2441.358209  5738.713270   56588.064516    26.838710
# 2021-01    15353.00  3719.515152  6150.523409   60861.596774    32.322581
# 2021-02     9748.00  2982.283333  5067.040161   34088.553571    12.071429
# 2021-03     4786.25  1844.194030  5241.408257   19151.774194    52.000000
# 2021-04     3656.50  1916.203125  5623.124413   20738.650000    65.433333
# 2021-05     4499.00  3568.969697  3019.465035   14985.822581    28.419355
# 2021-06     8627.50  4004.184615  1077.195652    7788.566667    32.433333
# 2021-07    15994.60  5289.439394   779.097838   12310.516129   142.129032
# 2021-08    14062.00  8228.666667  1228.426174   40434.629032   564.483871
# 2021-09     9622.50  6699.123077  1671.706776   44316.000000  1392.266667
# 2021-10     5028.60  3251.121212  2304.080738   27845.790323  1373.419355
# 2021-11     3092.50  2261.734375  3342.300242   23102.983333   675.766667
# 2021-12     6429.50  1689.253731  3542.228211   33358.725806   778.548387
# 2022-01     7789.40  2638.924242  4544.041761   72653.080645  4247.903226
# 2022-02     4140.00  5282.883333  4956.722151   40200.321429  3015.750000
# 2022-03     2509.75  4878.104478  3408.208178   12060.032258  1964.580645
# 2022-04     2103.60  1923.734375  3315.374269    8355.166667  3054.833333
# 2022-05         NaN   524.800000  4297.350877    8958.500000  3130.400000
#
# continent  South America
# month
# 2020-01              NaN
# 2020-02              NaN
# 2020-03              NaN
# 2020-04              NaN
# 2020-05              NaN
# 2020-06              NaN
# 2020-07              NaN
# 2020-08              NaN
# 2020-09              NaN
# 2020-10              NaN
# 2020-11              NaN
# 2020-12              NaN
# 2021-01              NaN
# 2021-02              NaN
# 2021-03              NaN
# 2021-04              NaN
# 2021-05      1825.416667
# 2021-06      2141.766667
# 2021-07      1276.419355
# 2021-08       820.709677
# 2021-09       589.733333
# 2021-10       478.032258
# 2021-11       604.100000
# 2021-12       866.000000
# 2022-01      1607.193548
# 2022-02       679.607143
# 2022-03       258.419355
# 2022-04       188.620690
# 2022-05              NaN

# %%
data3[['Africa','Asia','Europe', 'North America', 'Oceania', 'South America']].plot(figsize=(15,10))
plt.grid()
plt.title(column='month',fontsize=32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fn/xvvg6y_9405b165p72m0mk9h0000gn/T/ipykernel_81911/753399683.py in <module>
#       1 data3[['Africa','Asia','Europe', 'North America', 'Oceania', 'South America']].plot(figsize=(15,10))
#       2 plt.grid()
# ----> 3 plt.title(column,fontsize=32)
#
# NameError: name 'column' is not defined

# %% [markdown]
# e. create a discussion cell in which you discuss what your analysis tells you about the data
